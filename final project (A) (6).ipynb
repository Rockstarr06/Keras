# %%
import pandas as pd
import numpy as np

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
n_cols = predictors.shape[1] # number of predictors

# %%
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
def regression_model_A():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
modelA = regression_model_A()

# %%
modelA.fit(predictors, target, validation_split=0.3, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 1s - loss: 471731.1250 - val_loss: 302353.0938 - 608ms/epoch - 26ms/step
# Epoch 2/50
# 23/23 - 0s - loss: 247337.0156 - val_loss: 148484.2656 - 79ms/epoch - 3ms/step
# Epoch 3/50
# 23/23 - 0s - loss: 118436.2578 - val_loss: 65908.2031 - 78ms/epoch - 3ms/step
# Epoch 4/50
# 23/23 - 0s - loss: 51917.8477 - val_loss: 26483.0391 - 77ms/epoch - 3ms/step
# Epoch 5/50
# 23/23 - 0s - loss: 21486.1211 - val_loss: 10733.8467 - 78ms/epoch - 3ms/step
# Epoch 6/50
# 23/23 - 0s - loss: 9878.8662 - val_loss: 5734.5273 - 79ms/epoch - 3ms/step
# Epoch 7/50
# 23/23 - 0s - loss: 6291.8779 - val_loss: 4587.9370 - 78ms/epoch - 3ms/step
# Epoch 8/50
# 23/23 - 0s - loss: 5375.1870 - val_loss: 4434.7881 - 78ms/epoch - 3ms/step
# Epoch 9/50
# 23/23 - 0s - loss: 5131.9146 - val_loss: 4397.4595 - 79ms/epoch - 3ms/step
# Epoch 10/50
# 23/23 - 0s - loss: 5004.0454 - val_loss: 4333.2051 - 78ms/epoch - 3ms/step
# Epoch 11/50
# ...

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %%
print(n_cols)
# Out:
# 8

# %%
modelA.fit(predictors_norm, target, validation_split=0.3, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 0s - loss: 1642.6694 - val_loss: 1192.8075 - 147ms/epoch - 6ms/step
# Epoch 2/50
# 23/23 - 0s - loss: 1625.3127 - val_loss: 1180.1000 - 77ms/epoch - 3ms/step
# Epoch 3/50
# 23/23 - 0s - loss: 1609.3741 - val_loss: 1167.5073 - 79ms/epoch - 3ms/step
# Epoch 4/50
# 23/23 - 0s - loss: 1592.4547 - val_loss: 1153.7136 - 77ms/epoch - 3ms/step
# Epoch 5/50
# 23/23 - 0s - loss: 1572.7305 - val_loss: 1138.9135 - 78ms/epoch - 3ms/step
# Epoch 6/50
# 23/23 - 0s - loss: 1550.3734 - val_loss: 1122.9957 - 97ms/epoch - 4ms/step
# Epoch 7/50
# 23/23 - 0s - loss: 1525.6881 - val_loss: 1105.5024 - 82ms/epoch - 4ms/step
# Epoch 8/50
# 23/23 - 0s - loss: 1499.2207 - val_loss: 1086.9292 - 75ms/epoch - 3ms/step
# Epoch 9/50
# 23/23 - 0s - loss: 1471.2427 - val_loss: 1067.7998 - 78ms/epoch - 3ms/step
# Epoch 10/50
# 23/23 - 0s - loss: 1441.5571 - val_loss: 1049.0593 - 82ms/epoch - 4ms/step
# Epoch 11/50
# 23/23 - 0s - loss: 1411.7869 - val_loss: 1029.9230 - 74ms/epoch - 3ms/step
# ...

# %%
modelA.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 0s - loss: 486.7567 - val_loss: 453.6078 - 121ms/epoch - 5ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 473.9935 - val_loss: 445.7955 - 78ms/epoch - 3ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 461.7864 - val_loss: 438.2386 - 78ms/epoch - 3ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 450.0948 - val_loss: 431.1775 - 77ms/epoch - 3ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 438.7043 - val_loss: 424.2325 - 78ms/epoch - 3ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 427.8614 - val_loss: 417.3689 - 82ms/epoch - 4ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 417.5329 - val_loss: 410.8101 - 93ms/epoch - 4ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 407.5747 - val_loss: 404.6014 - 76ms/epoch - 3ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 398.0730 - val_loss: 398.7813 - 79ms/epoch - 3ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 389.0750 - val_loss: 392.5833 - 78ms/epoch - 3ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 380.2693 - val_loss: 387.2649 - 78ms/epoch - 3ms/step
# Epoch 12/100
# ...

# %%
def regression_model_D():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model
